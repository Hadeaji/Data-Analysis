# %%
import pandas as pd

df = pd.read_csv('./vgsales.csv')

print(df)
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# 1- Which company is the most common video game publisher?
rs =df[['Publisher']].value_counts().idxmax()[0]
print(rs)
# Out:
# Electronic Arts

# %%
# 2- What’s the most common platform?
rs =df[['Platform']].value_counts().idxmax()[0]
print(rs)
# Out:
# DS

# %%
# 3- What about the most common genre?
rs =df[['Genre']].value_counts().idxmax()[0]
print(rs)
# Out:
# Action

# %%
# 4- What are the top 20 highest grossing games?
rs = df[['Name','Global_Sales']].sort_values('Global_Sales', ascending=False).head(20)
print(rs)
# Out:
#                                             Name  Global_Sales
# 0                                     Wii Sports         82.74
# 1                              Super Mario Bros.         40.24
# 2                                 Mario Kart Wii         35.82
# 3                              Wii Sports Resort         33.00
# 4                       Pokemon Red/Pokemon Blue         31.37
# 5                                         Tetris         30.26
# 6                          New Super Mario Bros.         30.01
# 7                                       Wii Play         29.02
# 8                      New Super Mario Bros. Wii         28.62
# 9                                      Duck Hunt         28.31
# 10                                    Nintendogs         24.76
# 11                                 Mario Kart DS         23.42
# 12                   Pokemon Gold/Pokemon Silver         23.10
# 13                                       Wii Fit         22.72
# ...

# %%
# 5- For North American video game sales, what’s the median?


median = df[['NA_Sales']].median()[0]

# Provide a secondary output showing ten games surrounding the median sales output
# df1 = df[df['NA_Sales']>median].sort_values('NA_Sales', ascending=False).tail(5)
# df2 = df[df['NA_Sales']<median].sort_values('NA_Sales', ascending=False).head(5)

# # sorted (games with same median value) in descending order
# df1.sort_values('Rank', ascending=False)
# df2.sort_values('Rank', ascending=False)

# # merged the results
# result = df1.append(df2, sort=False)

# I checked the NA_Sales for the solution and it was = to the median
result = df[df['NA_Sales']==median].sort_values('Rank', ascending=False).head(10)

print(f'The Median Is {median}')
print(result)
# Out:
# The Median Is 0.08
#         Rank                                              Name Platform  \
# 11492  11494                      Ultimate Shooting Collection      Wii
# 11455  11457                                        The Hidden      3DS
# 11432  11434                              DanceDanceRevolution     X360
# 11431  11433  Little League World Series Baseball: Double Play       DS
# 11403  11405           My English Coach: Para Hispanoparlantes       DS
# 11390  11392      Super Robot Taisen OG Saga: Endless Frontier       DS
# 11386  11388                                     Sushi Academy       DS
# 11376  11378                         Face Racers: Photo Finish      3DS
# 11375  11377                   Dream Day: Wedding Destinations       DS
# 11371  11373            Death Jr. and the Science Fair of Doom       DS
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
# 6- For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?


highest_selling_game= df['NA_Sales'].head(1)[0]

std = df['NA_Sales'].std()

mean = df['NA_Sales'].mean()

# I took this equation from a TA lol
result=(highest_selling_game-mean)/std

print(result)
# Out:
# 50.47898767479108

# %%
# 7- The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

df1 = df[df['Publisher']=='Nintendo'][df['Platform']=='Wii']
df2 = df[df['Publisher']=='Nintendo'][df['Platform']!='Wii']

wii_mean = df1[['Global_Sales']].mean()[0]

not_wii_mean = df2[['Global_Sales']].mean()[0]

mean_diff = wii_mean - not_wii_mean

print(mean_diff)
# Out:
# 2.3929213785675816

# %%
# 8- Come up with 3 more questions that can be answered with this data set

# 1) Whish Genre Nintendo releases the most 

df1 = df[df['Publisher']=='Nintendo'][['Genre']].value_counts().idxmax()[0]
print(df1)

# 2) list of Publishers number of games that are in the top 100 game
df2 = df[df['Rank']<=100][['Publisher']].value_counts()
print(df2)

# 3) what is the top selling game in japan rank 
df3 = df.sort_values('JP_Sales', ascending=False).head(1)
print(df3.Rank.value_counts().idxmax())
# Out:
# Platform
# Publisher
# Nintendo                       52
# Activision                     14
# Take-Two Interactive            9
# Sony Computer Entertainment     8
# Microsoft Game Studios          6
# Electronic Arts                 5
# Ubisoft                         2
# SquareSoft                      1
# Sega                            1
# Bethesda Softworks              1
# Atari                           1
# dtype: int64
# 5
